# %% [markdown]
# ### 1.0 Testing Alpha Vantage
# Don't have old stock data (WAMU(Q) and LEHM(Q)) but current data (MSFT, AAPL) is easy to access

# %%
API_KEY = 'CMOPV1M5KTR8WKLE'

# %%
import re
from pprint import pprint
from alpha_vantage.timeseries import TimeSeries
from matplotlib import pyplot as plt

# %%
ts = TimeSeries(key=API_KEY, output_format='pandas')
# Get json object with the intraday data and another with  the call's metadata
data, meta_data = ts.get_intraday('AAPL')
pprint(meta_data)
# Out:
# {'1. Information': 'Intraday (15min) open, high, low, close prices and volume',
#  '2. Symbol': 'AAPL',
#  '3. Last Refreshed': '2018-12-18 16:00:00',
#  '4. Interval': '15min',
#  '5. Output Size': 'Compact',
#  '6. Time Zone': 'US/Eastern'}

# %%
data['4. close'].plot()
plt.title('Intraday Times Series for the MSFT stock (15 min)')
plt.show()

# %% [markdown]
# ### 2.0
