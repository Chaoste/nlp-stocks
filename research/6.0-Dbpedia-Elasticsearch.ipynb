# %%
from SPARQLWrapper import SPARQLWrapper, JSON

# %% [markdown]
# Examples: https://rdflib.github.io/sparqlwrapper/

# %%
sparql = SPARQLWrapper("http://dbpedia.org/sparql")
sparql.setQuery("""
    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    PREFIX dbo: <http://dbpedia.org/ontology/>
    PREFIX dbr: <http://dbpedia.org/resource/>
    PREFIX dbp: <http://dbpedia.org/property/>
    SELECT ?label
    WHERE { ?label dbp:tradedAs ?p
    FILTER (?p IN (<http://dbpedia.org/resource/S&P_500>, <http://dbpedia.org/resource/S&P_500_Index> ) ) }
""")
sparql.setReturnFormat(JSON)
results = sparql.query().convert()
print(f"{len(results['results']['bindings'])} Results:")
for result in results["results"]["bindings"]:
    print(result["label"]["value"])
# Out:
# 379 Results:
# http://dbpedia.org/resource/Texas_Instruments
# http://dbpedia.org/resource/Xerox
# http://dbpedia.org/resource/Robert_Half_International
# http://dbpedia.org/resource/CenturyLink
# http://dbpedia.org/resource/Dr_Pepper_Snapple_Group
# http://dbpedia.org/resource/Stericycle
# http://dbpedia.org/resource/Dentsply_Sirona
# http://dbpedia.org/resource/Diamond_Offshore_Drilling
# http://dbpedia.org/resource/Assurant
# http://dbpedia.org/resource/D._R._Horton
# http://dbpedia.org/resource/Edison_International
# http://dbpedia.org/resource/Illinois_Tool_Works
# http://dbpedia.org/resource/Microchip_Technology
# http://dbpedia.org/resource/ONEOK
# http://dbpedia.org/resource/SCANA
# http://dbpedia.org/resource/TSYS
# http://dbpedia.org/resource/United_Rentals
# http://dbpedia.org/resource/WEC_Energy_Group
# http://dbpedia.org/resource/XL_Catlin
# http://dbpedia.org/resource/Cognizant
# http://dbpedia.org/resource/Newfield_Exploration
# http://dbpedia.org/resource/Akamai_Technologies
# http://dbpedia.org/resource/Ball_Corporation
# http://dbpedia.org/resource/Berkshire_Hathaway
# http://dbpedia.org/resource/Boeing
# http://dbpedia.org/resource/Caterpillar_Inc.
# http://dbpedia.org/resource/CenterPoint_Energy
# http://dbpedia.org/resource/Consol_Energy
# http://dbpedia.org/resource/Discover_Financial
# http://dbpedia.org/resource/Discovery_Communications
# http://dbpedia.org/resource/DuPont
# http://dbpedia.org/resource/Duke_Energy
# http://dbpedia.org/resource/Eastman_Chemical_Company
# http://dbpedia.org/resource/Harris_Corporation
# http://dbpedia.org/resource/Hess_Corporation
# http://dbpedia.org/resource/Lockheed_Martin
# http://dbpedia.org/resource/Lowe's
# http://dbpedia.org/resource/Owens-Illinois
# http://dbpedia.org/resource/PNC_Financial_Services
# http://dbpedia.org/resource/PPG_Industries
# http://dbpedia.org/resource/PPL_Corporation
# http://dbpedia.org/resource/Pitney_Bowes
# http://dbpedia.org/resource/Praxair
# http://dbpedia.org/resource/Sprint_Corporation
# http://dbpedia.org/resource/TE_Connectivity
# http://dbpedia.org/resource/The_Mosaic_Company
# http://dbpedia.org/resource/The_Travelers_Companies
# http://dbpedia.org/resource/Tiffany_&_Co.
# http://dbpedia.org/resource/Tyco_International
# http://dbpedia.org/resource/UnitedHealth_Group
# http://dbpedia.org/resource/Wells_Fargo
# http://dbpedia.org/resource/Western_Union
# http://dbpedia.org/resource/Whirlpool_Corporation
# http://dbpedia.org/resource/Wyndham_Worldwide
# http://dbpedia.org/resource/American_Electric_Power
# http://dbpedia.org/resource/Boston_Scientific
# http://dbpedia.org/resource/E-Trade
# http://dbpedia.org/resource/Intuit
# http://dbpedia.org/resource/Adobe_Systems
# http://dbpedia.org/resource/Aon_(company)
# http://dbpedia.org/resource/Apple_Inc.
# http://dbpedia.org/resource/General_Electric
# http://dbpedia.org/resource/General_Motors
# http://dbpedia.org/resource/Intel
# http://dbpedia.org/resource/Mattel
# http://dbpedia.org/resource/Oracle_Corporation
# http://dbpedia.org/resource/Red_Hat
# http://dbpedia.org/resource/ACE_Limited
# http://dbpedia.org/resource/Bank_of_America
# http://dbpedia.org/resource/Delphi_Automotive
# http://dbpedia.org/resource/Devon_Energy
# http://dbpedia.org/resource/Eli_Lilly_and_Company
# http://dbpedia.org/resource/ExxonMobil
# http://dbpedia.org/resource/Gap_Inc.
# http://dbpedia.org/resource/General_Growth_Properties
# http://dbpedia.org/resource/Gilead_Sciences
# http://dbpedia.org/resource/Hospital_Corporation_of_America
# http://dbpedia.org/resource/IBM
# http://dbpedia.org/resource/Kohl's
# http://dbpedia.org/resource/McCormick_&_Company
# http://dbpedia.org/resource/Molson_Coors_Brewing_Company
# http://dbpedia.org/resource/Regions_Financial_Corporation
# http://dbpedia.org/resource/Danaher_Corporation
# http://dbpedia.org/resource/Spectra_Energy
# http://dbpedia.org/resource/Xcel_Energy
# http://dbpedia.org/resource/Yahoo!
# http://dbpedia.org/resource/EOG_Resources
# http://dbpedia.org/resource/Leggett_&_Platt
# http://dbpedia.org/resource/Universal_Health_Services
# http://dbpedia.org/resource/Equity_Residential
# http://dbpedia.org/resource/Kimco_Realty
# http://dbpedia.org/resource/LabCorp
# http://dbpedia.org/resource/Noble_Energy
# http://dbpedia.org/resource/The_Bank_of_New_York_Mellon
# http://dbpedia.org/resource/Torchmark
# http://dbpedia.org/resource/WestRock
# http://dbpedia.org/resource/C._R._Bard
# http://dbpedia.org/resource/HomeAway
# http://dbpedia.org/resource/AbbVie_Inc.
# http://dbpedia.org/resource/American_Airlines_Group
# http://dbpedia.org/resource/Norris_Production_Solutions
# http://dbpedia.org/resource/Prologis
# http://dbpedia.org/resource/Ralph_Lauren_Corporation
# http://dbpedia.org/resource/Zoetis
# http://dbpedia.org/resource/Motorola_Solutions
# http://dbpedia.org/resource/EBay
# http://dbpedia.org/resource/Nvidia
# http://dbpedia.org/resource/Time_Warner
# http://dbpedia.org/resource/Activision_Blizzard
# http://dbpedia.org/resource/Becton_Dickinson
# http://dbpedia.org/resource/Best_Buy
# http://dbpedia.org/resource/CA_Technologies
# http://dbpedia.org/resource/CME_Group
# http://dbpedia.org/resource/Cameron_International
# http://dbpedia.org/resource/Campbell_Soup_Company
# http://dbpedia.org/resource/Cigna
# http://dbpedia.org/resource/Colgate-Palmolive
# http://dbpedia.org/resource/Computer_Sciences_Corporation
# http://dbpedia.org/resource/ConocoPhillips
# http://dbpedia.org/resource/Cummins
# http://dbpedia.org/resource/Dollar_General
# http://dbpedia.org/resource/Eaton_Corporation
# http://dbpedia.org/resource/FIS_(company)
# http://dbpedia.org/resource/Halliburton
# http://dbpedia.org/resource/Honeywell
# http://dbpedia.org/resource/John_Deere
# http://dbpedia.org/resource/Lam_Research
# http://dbpedia.org/resource/Linear_Technology
# http://dbpedia.org/resource/Marsh_&_McLennan_Companies
# http://dbpedia.org/resource/MasterCard
# http://dbpedia.org/resource/O'Reilly_Auto_Parts
# http://dbpedia.org/resource/Patterson_Companies
# http://dbpedia.org/resource/PepsiCo
# http://dbpedia.org/resource/Philip_Morris_International
# http://dbpedia.org/resource/Phillips_66
# http://dbpedia.org/resource/Principal_Financial_Group
# http://dbpedia.org/resource/Rockwell_Automation
# http://dbpedia.org/resource/Rockwell_Collins
# http://dbpedia.org/resource/Seagate_Technology
# http://dbpedia.org/resource/Southern_Company
# http://dbpedia.org/resource/T._Rowe_Price
# http://dbpedia.org/resource/The_ADT_Corporation
# http://dbpedia.org/resource/Tyson_Foods
# http://dbpedia.org/resource/VF_Corporation
# http://dbpedia.org/resource/Yum!_Brands
# http://dbpedia.org/resource/Amazon.com
# http://dbpedia.org/resource/FedEx
# http://dbpedia.org/resource/Hasbro
# http://dbpedia.org/resource/Monsanto
# http://dbpedia.org/resource/F5_Networks
# http://dbpedia.org/resource/CF_Industries
# http://dbpedia.org/resource/Republic_Services
# http://dbpedia.org/resource/Verizon_Communications
# http://dbpedia.org/resource/Western_Refining
# http://dbpedia.org/resource/Symantec
# http://dbpedia.org/resource/NetApp
# http://dbpedia.org/resource/Hubbell_Incorporated
# http://dbpedia.org/resource/Xylem_Inc.
# http://dbpedia.org/resource/Alcoa
# http://dbpedia.org/resource/Analog_Devices
# http://dbpedia.org/resource/AutoZone
# http://dbpedia.org/resource/Automatic_Data_Processing
# http://dbpedia.org/resource/Avon_Products
# http://dbpedia.org/resource/Cardinal_Health
# http://dbpedia.org/resource/Chesapeake_Energy
# http://dbpedia.org/resource/Cisco_Systems
# http://dbpedia.org/resource/Citigroup
# http://dbpedia.org/resource/Consolidated_Edison
# http://dbpedia.org/resource/Corning_Inc.
# http://dbpedia.org/resource/Dow_Chemical_Company
# http://dbpedia.org/resource/Franklin_Templeton_Investments
# http://dbpedia.org/resource/Freeport-McMoRan
# http://dbpedia.org/resource/General_Dynamics
# http://dbpedia.org/resource/General_Mills
# http://dbpedia.org/resource/HP_Inc.
# http://dbpedia.org/resource/Hewlett_Packard_Enterprise
# http://dbpedia.org/resource/Huntington_Bancshares
# http://dbpedia.org/resource/International_Paper
# http://dbpedia.org/resource/KLA-Tencor
# http://dbpedia.org/resource/KeyBank
# http://dbpedia.org/resource/Kroger
# http://dbpedia.org/resource/Lincoln_National_Corporation
# http://dbpedia.org/resource/Marathon_Oil
# http://dbpedia.org/resource/Nike,_Inc.
# http://dbpedia.org/resource/Northern_Trust
# http://dbpedia.org/resource/Occidental_Petroleum
# http://dbpedia.org/resource/Progressive_Corporation
# http://dbpedia.org/resource/Quanta_Services
# http://dbpedia.org/resource/Tenet_Healthcare
# http://dbpedia.org/resource/The_Hartford
# http://dbpedia.org/resource/The_Home_Depot
# http://dbpedia.org/resource/United_Parcel_Service
# http://dbpedia.org/resource/Visa_Inc.
# http://dbpedia.org/resource/Biogen
# http://dbpedia.org/resource/Carnival_Corporation_&_plc
# http://dbpedia.org/resource/Coach,_Inc.
# http://dbpedia.org/resource/Comcast
# http://dbpedia.org/resource/Electronic_Arts
# http://dbpedia.org/resource/Estée_Lauder_Companies
# http://dbpedia.org/resource/Expeditors_International
# http://dbpedia.org/resource/L-3_Communications
# http://dbpedia.org/resource/Nordstrom
# http://dbpedia.org/resource/Pacific_Gas_and_Electric_Company
# http://dbpedia.org/resource/Qualcomm
# http://dbpedia.org/resource/Raytheon
# http://dbpedia.org/resource/Ryder
# http://dbpedia.org/resource/Hudson_City_Bancorp
# http://dbpedia.org/resource/Agilent_Technologies
# http://dbpedia.org/resource/Applied_Materials
# http://dbpedia.org/resource/Archer_Daniels_Midland
# http://dbpedia.org/resource/Autodesk
# http://dbpedia.org/resource/Baker_Hughes
# http://dbpedia.org/resource/Bed_Bath_&_Beyond
# http://dbpedia.org/resource/Bristol-Myers_Squibb
# http://dbpedia.org/resource/Chevron_Corporation
# http://dbpedia.org/resource/Comerica
# http://dbpedia.org/resource/Gannett_Company
# http://dbpedia.org/resource/Humana
# http://dbpedia.org/resource/JPMorgan_Chase
# http://dbpedia.org/resource/Kimberly-Clark
# http://dbpedia.org/resource/Macy's,_Inc.
# http://dbpedia.org/resource/MeadWestvaco
# http://dbpedia.org/resource/Northrop_Grumman
# http://dbpedia.org/resource/Omnicom_Group
# http://dbpedia.org/resource/Paccar
# http://dbpedia.org/resource/Paychex
# http://dbpedia.org/resource/Plum_Creek_Timber
# http://dbpedia.org/resource/S&P_Global
# http://dbpedia.org/resource/Staples_Inc.
# http://dbpedia.org/resource/Stryker_Corporation
# http://dbpedia.org/resource/Teradata
# http://dbpedia.org/resource/Tesoro
# http://dbpedia.org/resource/U.S._Bancorp
# http://dbpedia.org/resource/United_Technologies
# http://dbpedia.org/resource/Valero_Energy
# http://dbpedia.org/resource/Weyerhaeuser
# http://dbpedia.org/resource/Whole_Foods_Market
# http://dbpedia.org/resource/Dollar_Tree
# http://dbpedia.org/resource/Entergy
# http://dbpedia.org/resource/McKesson_Corporation
# http://dbpedia.org/resource/Newmont_Mining_Corporation
# http://dbpedia.org/resource/Public_Service_Enterprise_Group
# http://dbpedia.org/resource/Stanley_Black_&_Decker
# http://dbpedia.org/resource/Air_Products_&_Chemicals
# http://dbpedia.org/resource/Allstate
# http://dbpedia.org/resource/AmerisourceBergen
# http://dbpedia.org/resource/Amgen
# http://dbpedia.org/resource/BB&T
# http://dbpedia.org/resource/BlackRock
# http://dbpedia.org/resource/Boston_Properties
# http://dbpedia.org/resource/CBS_Corporation
# http://dbpedia.org/resource/CSX_Corporation
# http://dbpedia.org/resource/Charles_Schwab_Corporation
# http://dbpedia.org/resource/Chubb_Limited
# http://dbpedia.org/resource/Cincinnati_Financial
# http://dbpedia.org/resource/Clorox
# http://dbpedia.org/resource/ConAgra_Foods
# http://dbpedia.org/resource/Darden_Restaurants
# http://dbpedia.org/resource/Dun_&_Bradstreet
# http://dbpedia.org/resource/Equifax
# http://dbpedia.org/resource/Eversource_Energy
# http://dbpedia.org/resource/Exelon
# http://dbpedia.org/resource/Expedia,_Inc.
# http://dbpedia.org/resource/Fastenal
# http://dbpedia.org/resource/Fiserv
# http://dbpedia.org/resource/Invesco
# http://dbpedia.org/resource/Jabil_Circuit
# http://dbpedia.org/resource/Johnson_Controls
# http://dbpedia.org/resource/LyondellBasell
# http://dbpedia.org/resource/M&T_Bank
# http://dbpedia.org/resource/MetLife
# http://dbpedia.org/resource/Moody's_Corporation
# http://dbpedia.org/resource/Nucor
# http://dbpedia.org/resource/PerkinElmer
# http://dbpedia.org/resource/Sealed_Air
# http://dbpedia.org/resource/Skyworks_Solutions
# http://dbpedia.org/resource/Snap-on
# http://dbpedia.org/resource/SunTrust_Banks
# http://dbpedia.org/resource/Textron
# http://dbpedia.org/resource/The_Coca-Cola_Company
# http://dbpedia.org/resource/Transocean
# http://dbpedia.org/resource/Unum
# http://dbpedia.org/resource/Varian_Medical_Systems
# http://dbpedia.org/resource/Vulcan_Materials_Company
# http://dbpedia.org/resource/Hormel
# http://dbpedia.org/resource/Xilinx
# http://dbpedia.org/resource/Allergan,_Plc
# http://dbpedia.org/resource/OneSubsea
# http://dbpedia.org/resource/Talen_Energy
# http://dbpedia.org/resource/Welltower
# http://dbpedia.org/resource/CSRA_(IT_services_company)
# http://dbpedia.org/resource/Ameren
# http://dbpedia.org/resource/Kinder_Morgan
# http://dbpedia.org/resource/Endo_International_plc
# http://dbpedia.org/resource/Parker_Hannifin
# http://dbpedia.org/resource/Cabot_Oil_&_Gas
# http://dbpedia.org/resource/Constellation_Brands
# http://dbpedia.org/resource/Dominion_Resources
# http://dbpedia.org/resource/Fifth_Third_Bank
# http://dbpedia.org/resource/Loews_Corporation
# http://dbpedia.org/resource/Marriott_International
# http://dbpedia.org/resource/Merck_&_Co.
# http://dbpedia.org/resource/The_Priceline_Group
# http://dbpedia.org/resource/Novavax
# http://dbpedia.org/resource/Affiliated_Managers_Group
# http://dbpedia.org/resource/Alexion_Pharmaceuticals
# http://dbpedia.org/resource/AvalonBay_Communities
# http://dbpedia.org/resource/Range_Resources
# http://dbpedia.org/resource/Garmin
# http://dbpedia.org/resource/HP_SiteScope
# http://dbpedia.org/resource/3M
# http://dbpedia.org/resource/FLIR_Systems
# http://dbpedia.org/resource/Intercontinental_Exchange
# http://dbpedia.org/resource/J._B._Hunt
# http://dbpedia.org/resource/People's_United_Financial
# http://dbpedia.org/resource/Rust-Oleum
# http://dbpedia.org/resource/Zions_Bancorporation
# http://dbpedia.org/resource/AT&T
# http://dbpedia.org/resource/EQT
# http://dbpedia.org/resource/Synchrony_Financial
# http://dbpedia.org/resource/Pioneer_Natural_Resources
# http://dbpedia.org/resource/Willis_Towers_Watson
# http://dbpedia.org/resource/List_of_assets_owned_by_Berkshire_Hathaway
# http://dbpedia.org/resource/TJX_Companies
# http://dbpedia.org/resource/Wynn_Resorts
# http://dbpedia.org/resource/CBRE_Group
# http://dbpedia.org/resource/Murphy_Oil
# http://dbpedia.org/resource/NRG_Energy
# http://dbpedia.org/resource/Perrigo
# http://dbpedia.org/resource/Vornado_Realty_Trust
# http://dbpedia.org/resource/FMC_Technologies
# http://dbpedia.org/resource/Jacobs_Engineering_Group
# http://dbpedia.org/resource/Mead_Johnson
# http://dbpedia.org/resource/Apache_Corporation
# http://dbpedia.org/resource/BorgWarner
# http://dbpedia.org/resource/Brown-Forman
# http://dbpedia.org/resource/C._H._Robinson
# http://dbpedia.org/resource/CarMax
# http://dbpedia.org/resource/Celgene
# http://dbpedia.org/resource/Cerner
# http://dbpedia.org/resource/Cintas
# http://dbpedia.org/resource/DaVita
# http://dbpedia.org/resource/FirstEnergy
# http://dbpedia.org/resource/Fluor_Corporation
# http://dbpedia.org/resource/Harman_International_Industries
# http://dbpedia.org/resource/Host_Hotels_&_Resorts
# http://dbpedia.org/resource/Intuitive_Surgical
# http://dbpedia.org/resource/Leucadia_National
# http://dbpedia.org/resource/Masco
# http://dbpedia.org/resource/Mylan
# http://dbpedia.org/resource/National_Oilwell_Varco
# http://dbpedia.org/resource/PVH_(company)
# http://dbpedia.org/resource/Pentair
# http://dbpedia.org/resource/Public_Storage
# http://dbpedia.org/resource/PulteGroup
# http://dbpedia.org/resource/Reynolds_American
# http://dbpedia.org/resource/Roper_Technologies
# http://dbpedia.org/resource/Salesforce.com
# http://dbpedia.org/resource/Sempra_Energy
# http://dbpedia.org/resource/Sherwin-Williams
# http://dbpedia.org/resource/St._Jude_Medical
# http://dbpedia.org/resource/Sysco
# http://dbpedia.org/resource/TripAdvisor
# http://dbpedia.org/resource/Waste_Management_(corporation)
# http://dbpedia.org/resource/Williams_Companies
# http://dbpedia.org/resource/Schlumberger
# http://dbpedia.org/resource/Fortive
# http://dbpedia.org/resource/21st_Century_Fox
# http://dbpedia.org/resource/American_International_Group
# http://dbpedia.org/resource/Microsoft
# http://dbpedia.org/resource/News_Corp
# http://dbpedia.org/resource/The_Walt_Disney_Company
# http://dbpedia.org/resource/American_Express
# http://dbpedia.org/resource/Goldman_Sachs
# http://dbpedia.org/resource/Morgan_Stanley
# http://dbpedia.org/resource/Nasdaq,_Inc.
# http://dbpedia.org/resource/Newell_Brands
# http://dbpedia.org/resource/Verisign
# http://dbpedia.org/resource/AutoNation

# %% [markdown]
# ### DBpedia Spotlight

# %%
import spotlight

# %%
# News from SAP Qualtrics Deal -> Recognizes Qualtrics and SAP SE
annotations = spotlight.annotate('https://api.dbpedia-spotlight.org/en/annotate',
                                 'The tech industry’s newest billionaires are a pair of brothers who started a software company in their parents’ basement in Utah. Now Ryan and Jared Smith are selling Qualtrics International Inc. to European giant SAP SE for $8 billion — and they’ll get to keep running the business.',
                                 confidence=0.5, support=0)
[x for x in annotations if 'Company' in x['types']]
# Out:
# [{'URI': 'http://dbpedia.org/resource/Qualtrics',
#   'support': 16,
#   'types': 'Wikidata:Q43229,Wikidata:Q24229398,DUL:SocialPerson,DUL:Agent,Schema:Organization,DBpedia:Organisation,DBpedia:Company,DBpedia:Agent',
#   'surfaceForm': 'Qualtrics',
#   'offset': 167,
#   'similarityScore': 1.0,
#   'percentageOfSecondRank': 0.0},
#  {'URI': 'http://dbpedia.org/resource/SAP_SE',
#   'support': 1908,
#   'types': 'Wikidata:Q43229,Wikidata:Q24229398,DUL:SocialPerson,DUL:Agent,Schema:Organization,DBpedia:Organisation,DBpedia:Company,DBpedia:Agent',
#   'surfaceForm': 'SAP SE',
#   'offset': 214,
#   'similarityScore': 1.0,
#   'percentageOfSecondRank': 0.0}]

# %% [markdown]
# ### Elasticsearch

# %% [markdown]
# Guide: https://www.elastic.co/guide/en/elasticsearch/reference/master/search-aggregations-bucket-significanttext-aggregation.html
#
# Docs: https://elasticsearch-py.readthedocs.io/en/master/api.html

# %%
from datetime import datetime
from elasticsearch import Elasticsearch

IP_ADDRESS = 'http://172.16.64.23:9200'
es = Elasticsearch([IP_ADDRESS])
index = 'bloomberg_reuters'

# %%
 es.indices.get_alias("*")
# Out:
# {'new_guardian': {'aliases': {}},
#  'ss': {'aliases': {}},
#  '.monitoring-es-6-2018.11.20': {'aliases': {}},
#  'wpi': {'aliases': {}},
#  'new_dailymail': {'aliases': {}},
#  'new_telegraph': {'aliases': {}},
#  'shakespeare': {'aliases': {}},
#  'new_independent': {'aliases': {}},
#  'bloomberg_reuters': {'aliases': {}},
#  'semantic-scholar': {'aliases': {}},
#  '.monitoring-kibana-6-2018.11.20': {'aliases': {}},
#  '.monitoring-es-6-2018.11.21': {'aliases': {}},
#  '.monitoring-kibana-6-2018.11.21': {'aliases': {}},
#  'new_rssfeedbbc': {'aliases': {}},
#  'quagga_enron': {'aliases': {}},
#  '.kibana_1': {'aliases': {'.kibana': {}}}}

# %%
es.count(index)
# Out:
# {'count': 554914,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0}}

# %%
res = es.search(index=index, body={
    "query": {"match" : {"article": "volkswagen"}},
    "size": 0,
    "aggregations" : {
       "my_sample" : {
           "sampler" : {
               "shard_size" : 5000
           },
           "aggregations": {
               "keywords" : {
                   "significant_text" : { "field" : "article" }
               }
           }
       }
   }
})
print("%d documents found" % res['hits']['total'])
# print(res)
for bucket in res['aggregations']['my_sample']['keywords']['buckets']:
    print(f"{bucket['key']} - Count={bucket['doc_count']}; Score={bucket['score']}; Bg_count={bucket['bg_count']}")
# Out:
# 4046 documents found
# volkswagen - Count=4046; Score=136.15126050420167; Bg_count=4046
# vow - Count=1809; Score=45.94792416756137; Bg_count=2391
# vw - Count=1118; Score=35.691342459519795; Bg_count=1178
# audi - Count=1123; Score=27.482010773572004; Bg_count=1540
# wolfsburg - Count=575; Score=16.412570251634154; Bg_count=677
# porsche - Count=757; Score=16.302891677934706; Bg_count=1178
# motoren - Count=903; Score=15.680570757416096; Bg_count=1738
# werke - Count=902; Score=15.500860141336506; Bg_count=1754
# bmw - Count=979; Score=14.406013583744956; Bg_count=2218
# carmaker - Count=1694; Score=14.333345124795336; Bg_count=6594
